# %%
import pandas as pd

df = pd.read_excel('data.xlsx')

# %%
col = 'Category,Item Name,Item URL,Item URI,Attribute 1,Value 1,Schema URI 1,Attribute 2,Value 2,Schema URI 2,Attribute 3,Value 3,Schema URI 3,Attribute 4,Value 4,Schema URI 4,Attribute 5,Value 5,Schema URI 5'

cols = col.split(',')
cols
# Out:
# ['Category',
#  'Item Name',
#  'Item URL',
#  'Item URI',
#  'Attribute 1',
#  'Value 1',
#  'Schema URI 1',
#  'Attribute 2',
#  'Value 2',
#  'Schema URI 2',
#  'Attribute 3',
#  'Value 3',
#  'Schema URI 3',
#  'Attribute 4',
#  'Value 4',
#  'Schema URI 4',
#  'Attribute 5',
#  'Value 5',
#  'Schema URI 5']

# %%
df.columns = cols
df
# Out:
#                                Category  \
# 0                                switch
# 1                                switch
# 2                                switch
# 3                                switch
# 4                                switch
# 5                                switch
# 6                                switch
# 7                         switch_bundle
# 8                         switch_bundle
# 9                             accessory
# 10                            accessory
# 11                    games,new_product
# 12                                games
# 13                                games
# 14          games,new_product,franchise
# 15                                games
# 16                    games,new_product
# 17                    games,new_product
# 18                                games
# 19                                games
# 20                                games
# 21                                games
# ...

# %%
df.to_csv('group-14_ken3140_webshop.csv',index=False)
